# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

# %%
from ultralytics import YOLO

model = YOLO()  # or YOLO("yolo11n.yaml") / YOLO("your_model.pt")

results = model.train(
    data="coco8.yaml",
    batch= 4,
    epochs=10,
    imgsz=640,
    device= 0,
    pretrained=False,

    # dual teacher-student (full net = teacher, subnet = student)
    dual_channel_ratio=3,
    dual_channel_loss_weight=1.0,

    # 1) KL classification distillation
    cls_dist=True,
    cls_alpha=1.0,
    cls_dist_t=2.0,

    # 2) M2D2 distillation
    m2d2_dist=True,
    m2d2_alpha=1.0,
    m2d2_t=2.0,

    # 3) L2 bbox distillation
    l2_dist=True,
    l2_alpha=1.0,

    # adaptive alpha controls
    adaptive_distill_alpha=True,
    adaptive_alpha_momentum=0.9,
    adaptive_alpha_min_scale=0.25,
    adaptive_alpha_max_scale=4.0,

    # masking/weighting knobs (only applied for enabled methods)
    cls_fg_mask=True,      # only matters if cls_dist=True
    # dfl_fg_mask=True,      # M2D2 now always gets TAL masks when enabled
    l2_fg_mask=True,       # used since l2_dist=True
    mask_type="pyramid",  # "original" or "pyramid"
    level_weights=[1.0, 1.0, 1.0],

    print_bn_params_dims=True,
)
# Out:
# No model path provided. Building hardcoded YOLO11n with random initialization.
# WARNING Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# New https://pypi.org/project/ultralytics/8.4.14 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.184  Python-3.13.5 torch-2.9.0+cu130 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# engine\trainer: adaptive_alpha_max_scale=4.0, adaptive_alpha_min_scale=0.25, adaptive_alpha_momentum=0.9, adaptive_distill_alpha=True, agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=4, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_alpha=1.0, cls_dist=True, cls_dist_t=2.0, cls_fg_mask=True, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=coco8.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dfl_fg_mask=False, dnn=False, dropout=0.0, dual_channel_loss_weight=1.0, dual_channel_ratio=3, dynamic=False, embed=None, epochs=10, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, l2_alpha=1.0, l2_dist=True, l2_fg_mask=True, level_weights=[1.0, 1.0, 1.0], line_width=None, lr0=0.01, lrf=0.01, m2d2_alpha=1.0, m2d2_dist=True, m2d2_t=2.0, mask_ratio=4, mask_type=pyramid, max_det=300, mixup=0.0, mode=train, model=yolo11n.yaml, momentum=0.937, mosaic=1.0, multi_scale=False, name=train4, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=False, print_bn_params_dims=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=D:\self_distillation\runs\detect\train4, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Using hardcoded YOLO11n architecture with random initialization (pretrained=False).
# hardcoded_YOLO11n summary: 181 layers, 20,728,624 parameters, 20,728,608 gradients
#
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.10.0 ms, read: 265.8117.3 MB/s, size: 50.0 KB)
# train: Scanning D:\datasets\coco8\labels\train.cache... 4 images, 0 backgrounds, 0 corrupt: 100%|██████████| 4/4 [00:00
# val: Fast image access  (ping: 0.10.0 ms, read: 207.569.2 MB/s, size: 54.0 KB)
# val: Scanning D:\datasets\coco8\labels\val.cache... 4 images, 0 backgrounds, 0 corrupt: 100%|██████████| 4/4 [00:00<?,
# Plotting labels to D:\self_distillation\runs\detect\train4\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000119, momentum=0.9) with parameter groups 162 weight(decay=0.0), 88 weight(decay=0.0005), 168 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to D:\self_distillation\runs\detect\train4
# Starting training for 10 epochs...
# Closing dataloader mosaic
#
#       Epoch    GPU_memteacher_box_lossteacher_cls_lossteacher_dfl_lossstudent_box_lossstudent_cls_lossstudent_dfl_lossdistill_cls_lossdistill_m2d2_lossdistill_l2_loss  Instances       Size
# Epoch=1/10 | GPU=2.92G | Teacher(teacher_box_loss=3.116, teacher_cls_loss=5.786, teacher_dfl_loss=4.248) | Student(student_box_loss=3.171, student_cls_loss=5.692, student_dfl_loss=4.308) | Distill(distill_cls_loss=0.7673, distill_m2d2_loss=0.1705, distill_l2_loss=0.003178) | Instances=13 | Size=640: 100%|██████████| 1/1 [00:08<00:00,  8.90s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<0
#                    all          4         17          0          0          0          0
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<0
#                    all          4         17          0          0          0          0
# Student subnet metrics: P=0.0000, R=0.0000, mAP50=0.0000, mAP50-95=0.0000
#       Epoch    GPU_memteacher_box_lossteacher_cls_lossteacher_dfl_lossstudent_box_lossstudent_cls_lossstudent_dfl_lossdistill_cls_lossdistill_m2d2_lossdistill_l2_loss  Instances       Size
# Epoch=2/10 | GPU=2.97G | Teacher(teacher_box_loss=2.915, teacher_cls_loss=5.721, teacher_dfl_loss=4.221) | Student(student_box_loss=2.948, student_cls_loss=5.751, student_dfl_loss=4.219) | Distill(distill_cls_loss=0.2023, distill_m2d2_loss=0.0414, distill_l2_loss=0.0009177) | Instances=13 | Size=640: 100%|██████████| 1/1 [00:00<00:00,  1.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<0
#                    all          4         17          0          0          0          0
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<0
#                    all          4         17          0          0          0          0
# Student subnet metrics: P=0.0000, R=0.0000, mAP50=0.0000, mAP50-95=0.0000
#
#       Epoch    GPU_memteacher_box_lossteacher_cls_lossteacher_dfl_lossstudent_box_lossstudent_cls_lossstudent_dfl_lossdistill_cls_lossdistill_m2d2_lossdistill_l2_loss  Instances       Size
# Epoch=3/10 | GPU=2.97G | Teacher(teacher_box_loss=2.963, teacher_cls_loss=5.775, teacher_dfl_loss=4.355) | Student(student_box_loss=2.986, student_cls_loss=5.723, student_dfl_loss=4.223) | Distill(distill_cls_loss=0.2547, distill_m2d2_loss=0.07424, distill_l2_loss=0.001853) | Instances=13 | Size=640: 100%|██████████| 1/1 [00:00<00:00,  1.50it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<0
#                    all          4         17          0          0          0          0
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<0
#                    all          4         17          0          0          0          0
# Student subnet metrics: P=0.0000, R=0.0000, mAP50=0.0000, mAP50-95=0.0000
#
#       Epoch    GPU_memteacher_box_lossteacher_cls_lossteacher_dfl_lossstudent_box_lossstudent_cls_lossstudent_dfl_lossdistill_cls_lossdistill_m2d2_lossdistill_l2_loss  Instances       Size
# Epoch=4/10 | GPU=2.98G | Teacher(teacher_box_loss=2.745, teacher_cls_loss=5.653, teacher_dfl_loss=4.182) | Student(student_box_loss=2.733, student_cls_loss=5.587, student_dfl_loss=4.236) | Distill(distill_cls_loss=0.5612, distill_m2d2_loss=0.1361, distill_l2_loss=0.003118) | Instances=13 | Size=640: 100%|██████████| 1/1 [00:00<00:00,  1.59it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<0
#                    all          4         17          0          0          0          0
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<0
#                    all          4         17          0          0          0          0
# Student subnet metrics: P=0.0000, R=0.0000, mAP50=0.0000, mAP50-95=0.0000
#
#       Epoch    GPU_memteacher_box_lossteacher_cls_lossteacher_dfl_lossstudent_box_lossstudent_cls_lossstudent_dfl_lossdistill_cls_lossdistill_m2d2_lossdistill_l2_loss  Instances       Size
# Epoch=5/10 | GPU=2.98G | Teacher(teacher_box_loss=3.182, teacher_cls_loss=5.721, teacher_dfl_loss=4.365) | Student(student_box_loss=3.171, student_cls_loss=5.691, student_dfl_loss=4.328) | Distill(distill_cls_loss=1.038, distill_m2d2_loss=0.2813, distill_l2_loss=0.006019) | Instances=13 | Size=640: 100%|██████████| 1/1 [00:00<00:00,  1.59it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<0
#                    all          4         17          0          0          0          0
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<0
#                    all          4         17          0          0          0          0
# Student subnet metrics: P=0.0000, R=0.0000, mAP50=0.0000, mAP50-95=0.0000
#
#       Epoch    GPU_memteacher_box_lossteacher_cls_lossteacher_dfl_lossstudent_box_lossstudent_cls_lossstudent_dfl_lossdistill_cls_lossdistill_m2d2_lossdistill_l2_loss  Instances       Size
# Epoch=6/10 | GPU=3.06G | Teacher(teacher_box_loss=3.101, teacher_cls_loss=5.645, teacher_dfl_loss=4.328) | Student(student_box_loss=3.075, student_cls_loss=5.656, student_dfl_loss=4.267) | Distill(distill_cls_loss=0.7732, distill_m2d2_loss=0.1476, distill_l2_loss=0.003244) | Instances=13 | Size=640: 100%|██████████| 1/1 [00:00<00:00,  1.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<0
#                    all          4         17          0          0          0          0
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<0
#                    all          4         17          0          0          0          0
# Student subnet metrics: P=0.0000, R=0.0000, mAP50=0.0000, mAP50-95=0.0000
#
#       Epoch    GPU_memteacher_box_lossteacher_cls_lossteacher_dfl_lossstudent_box_lossstudent_cls_lossstudent_dfl_lossdistill_cls_lossdistill_m2d2_lossdistill_l2_loss  Instances       Size
# Epoch=7/10 | GPU=2.97G | Teacher(teacher_box_loss=2.868, teacher_cls_loss=5.648, teacher_dfl_loss=4.208) | Student(student_box_loss=2.799, student_cls_loss=5.551, student_dfl_loss=4.348) | Distill(distill_cls_loss=0.4875, distill_m2d2_loss=0.1124, distill_l2_loss=0.001933) | Instances=13 | Size=640: 100%|██████████| 1/1 [00:00<00:00,  1.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<0
#                    all          4         17          0          0          0          0
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<0
#                    all          4         17          0          0          0          0
# Student subnet metrics: P=0.0000, R=0.0000, mAP50=0.0000, mAP50-95=0.0000
#
#       Epoch    GPU_memteacher_box_lossteacher_cls_lossteacher_dfl_lossstudent_box_lossstudent_cls_lossstudent_dfl_lossdistill_cls_lossdistill_m2d2_lossdistill_l2_loss  Instances       Size
# Epoch=8/10 | GPU=3.06G | Teacher(teacher_box_loss=2.803, teacher_cls_loss=6.008, teacher_dfl_loss=4.337) | Student(student_box_loss=3.059, student_cls_loss=5.877, student_dfl_loss=4.317) | Distill(distill_cls_loss=1.379, distill_m2d2_loss=0.3241, distill_l2_loss=0.007036) | Instances=13 | Size=640: 100%|██████████| 1/1 [00:00<00:00,  1.46it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<0
#                    all          4         17          0          0          0          0
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<0
#                    all          4         17          0          0          0          0
# Student subnet metrics: P=0.0000, R=0.0000, mAP50=0.0000, mAP50-95=0.0000
#       Epoch    GPU_memteacher_box_lossteacher_cls_lossteacher_dfl_lossstudent_box_lossstudent_cls_lossstudent_dfl_lossdistill_cls_lossdistill_m2d2_lossdistill_l2_loss  Instances       Size
# Epoch=9/10 | GPU=2.99G | Teacher(teacher_box_loss=2.88, teacher_cls_loss=5.743, teacher_dfl_loss=4.446) | Student(student_box_loss=2.886, student_cls_loss=5.692, student_dfl_loss=4.37) | Distill(distill_cls_loss=0.7093, distill_m2d2_loss=0.1927, distill_l2_loss=0.003969) | Instances=13 | Size=640: 100%|██████████| 1/1 [00:00<00:00,  1.64it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<0
#                    all          4         17          0          0          0          0
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<0
#                    all          4         17          0          0          0          0
# Student subnet metrics: P=0.0000, R=0.0000, mAP50=0.0000, mAP50-95=0.0000
#
#       Epoch    GPU_memteacher_box_lossteacher_cls_lossteacher_dfl_lossstudent_box_lossstudent_cls_lossstudent_dfl_lossdistill_cls_lossdistill_m2d2_lossdistill_l2_loss  Instances       Size
# Epoch=10/10 | GPU=3.07G | Teacher(teacher_box_loss=2.814, teacher_cls_loss=5.675, teacher_dfl_loss=4.322) | Student(student_box_loss=2.774, student_cls_loss=5.635, student_dfl_loss=4.264) | Distill(distill_cls_loss=0.7478, distill_m2d2_loss=0.1584, distill_l2_loss=0.003124) | Instances=13 | Size=640: 100%|██████████| 1/1 [00:00<00:00,  1.53it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<0
#                    all          4         17          0          0          0          0
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<0
#                    all          4         17          0          0          0          0
# Student subnet metrics: P=0.0000, R=0.0000, mAP50=0.0000, mAP50-95=0.0000
#
# 10 epochs completed in 0.010 hours.
# Optimizer stripped from D:\self_distillation\runs\detect\train4\weights\last.pt, 42.0MB
# Optimizer stripped from D:\self_distillation\runs\detect\train4\weights\best.pt, 42.0MB
#
# Validating D:\self_distillation\runs\detect\train4\weights\best.pt...
# Ultralytics 8.3.184  Python-3.13.5 torch-2.9.0+cu130 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# hardcoded_YOLO11n summary (fused): 100 layers, 20,661,736 parameters, 0 gradients
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<0
#                    all          4         17          0          0          0          0
#                 person          3         10          0          0          0          0
#                    dog          1          1          0          0          0          0
#                  horse          1          2          0          0          0          0
#               elephant          1          2          0          0          0          0
#               umbrella          1          1          0          0          0          0
#           potted plant          1          1          0          0          0          0
# Speed: 3.9ms preprocess, 83.7ms inference, 0.0ms loss, 0.4ms postprocess per image
# Results saved to D:\self_distillation\runs\detect\train4
# Optimizer stripped from D:\self_distillation\runs\detect\train4\weights\last_student.pt, 5.5MB
# Optimizer stripped from D:\self_distillation\runs\detect\train4\weights\best_student.pt, 5.5MB
#
# Validating D:\self_distillation\runs\detect\train4\weights\best_student.pt...
# Ultralytics 8.3.184  Python-3.13.5 torch-2.9.0+cu130 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# hardcoded_YOLO11n summary (fused): 100 layers, 2,616,248 parameters, 0 gradients
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<0
#                    all          4         17          0          0          0          0
#                      0          3         10          0          0          0          0
#                     16          1          1          0          0          0          0
#                     17          1          2          0          0          0          0
#                     20          1          2          0          0          0          0
#                     25          1          1          0          0          0          0
#                     58          1          1          0          0          0          0
# Speed: 3.1ms preprocess, 397.5ms inference, 0.0ms loss, 1.8ms postprocess per image
# Results saved to D:\self_distillation\runs\detect\train4
