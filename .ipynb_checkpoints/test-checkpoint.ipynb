# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

# %%
# from ultralytics import YOLO

# model = YOLO()  # or your model yaml/pt

# results = model.train(
#     data="coco8.yaml",
#     epochs=2,
#     imgsz=640,
#     pretrained=False,

#     # dual teacher-student (full net = teacher, subnet = student)
#     dual_channel_ratio=3,
#     dual_channel_loss_weight=1.0,

#     # 1) KL classification distillation
#     cls_dist=False,    # explicit on/off
#     cls_alpha=1.0,     # base alpha (used only if cls_dist=True)
#     cls_dist_t=2.0,

#     # 2) M2D2 distillation
#     m2d2_dist=False,    # explicit on/off
#     m2d2_alpha=1.0,    # base alpha
#     m2d2_t=2.0,

#     # 3) L2 bbox distillation
#     l2_dist=True,      # explicit on/off
#     l2_alpha=1.0,      # base alpha

#     # adaptive alpha controls (optional)
#     adaptive_distill_alpha=True,
#     adaptive_alpha_momentum=0.9,
#     adaptive_alpha_min_scale=0.25,
#     adaptive_alpha_max_scale=4.0,

#     # optional masking/weighting knobs
#     cls_fg_mask=True,
#     dfl_fg_mask=True,
#     l2_fg_mask=True,
#     mask_type="original",          # "original" or "pyramid"
#     level_weights=[1.0, 1.0, 1.0],

#     print_bn_params_dims=True,
# )

# %%
from ultralytics import YOLO

model = YOLO()  # or YOLO("yolo11n.yaml") / YOLO("your_model.pt")

results = model.train(
    data="coco8.yaml",
    epochs=2,
    imgsz=640,
    pretrained=False,

    # dual teacher-student (full net = teacher, subnet = student)
    dual_channel_ratio=3,
    dual_channel_loss_weight=1.0,

    # 1) KL classification distillation
    cls_dist=True,
    cls_alpha=1.0,
    cls_dist_t=2.0,

    # 2) M2D2 distillation
    m2d2_dist=True,
    m2d2_alpha=1.0,
    m2d2_t=2.0,

    # 3) L2 bbox distillation
    l2_dist=True,
    l2_alpha=1.0,

    # adaptive alpha controls
    adaptive_distill_alpha=True,
    adaptive_alpha_momentum=0.9,
    adaptive_alpha_min_scale=0.25,
    adaptive_alpha_max_scale=4.0,

    # masking/weighting knobs (only applied for enabled methods)
    cls_fg_mask=True,      # only matters if cls_dist=True
    # dfl_fg_mask=True,      # M2D2 now always gets TAL masks when enabled
    l2_fg_mask=True,       # used since l2_dist=True
    mask_type="pyramid",  # "original" or "pyramid"
    level_weights=[1.0, 1.0, 1.0],

    print_bn_params_dims=True,
)
# Out:
# No model path provided. Building hardcoded YOLO11n with random initialization.
# WARNING Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# New https://pypi.org/project/ultralytics/8.4.14 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.184  Python-3.12.4 torch-2.5.1+cpu CPU (Intel Core(TM) i7-4700HQ 2.40GHz)
# engine\trainer: adaptive_alpha_max_scale=4.0, adaptive_alpha_min_scale=0.25, adaptive_alpha_momentum=0.9, adaptive_distill_alpha=True, agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_alpha=1.0, cls_dist=True, cls_dist_t=2.0, cls_fg_mask=True, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=coco8.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dfl_fg_mask=False, dnn=False, dropout=0.0, dual_channel_loss_weight=1.0, dual_channel_ratio=3, dynamic=False, embed=None, epochs=2, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, l2_alpha=1.0, l2_dist=True, l2_fg_mask=True, level_weights=[1.0, 1.0, 1.0], line_width=None, lr0=0.01, lrf=0.01, m2d2_alpha=1.0, m2d2_dist=True, m2d2_t=2.0, mask_ratio=4, mask_type=pyramid, max_det=300, mixup=0.0, mode=train, model=yolo11n.yaml, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=False, print_bn_params_dims=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs\detect\train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Using hardcoded YOLO11n architecture with random initialization (pretrained=False).
# hardcoded_YOLO11n summary: 181 layers, 20,728,624 parameters, 20,728,608 gradients, 46.3 GFLOPs
#
# Freezing layer 'model.23.dfl.conv.weight'
# train: Fast image access  (ping: 0.10.0 ms, read: 226.569.8 MB/s, size: 50.0 KB)
# train: Scanning E:\00.MOTHER_BOXES\code\modification\datasets\coco8\labels\train.cache... 4 images, 0 backgrounds, 0 co
# val: Fast image access  (ping: 0.10.0 ms, read: 264.277.9 MB/s, size: 54.0 KB)
# val: Scanning E:\00.MOTHER_BOXES\code\modification\datasets\coco8\labels\val.cache... 4 images, 0 backgrounds, 0 corrup
# Plotting labels to runs\detect\train\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000119, momentum=0.9) with parameter groups 162 weight(decay=0.0), 88 weight(decay=0.0005), 168 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to runs\detect\train
# Starting training for 2 epochs...
#
# Teacher+Distill | Epoch | GPU_mem | teacher_box_loss | teacher_cls_loss | teacher_dfl_loss | distill_cls_loss | distill_m2d2_loss | distill_l2_loss | Instances | Size
# Student        | Epoch | GPU_mem | student_box_loss | student_cls_loss | student_dfl_loss | Instances | Size
# Teacher+Distill | Epoch: 1/2 | GPU_mem: 0G | teacher_box_loss: 2.914 | teacher_cls_loss: 5.588 | teacher_dfl_loss: 4.27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:18<0
#                    all          4         17          0          0          0          0
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<0
#                    all          4         17          0          0          0          0
# Student subnet metrics: P=0.0000, R=0.0000, mAP50=0.0000, mAP50-95=0.0000
# Teacher+Distill | Epoch | GPU_mem | teacher_box_loss | teacher_cls_loss | teacher_dfl_loss | distill_cls_loss | distill_m2d2_loss | distill_l2_loss | Instances | Size
# Student        | Epoch | GPU_mem | student_box_loss | student_cls_loss | student_dfl_loss | Instances | Size
# Teacher+Distill | Epoch: 2/2 | GPU_mem: 0G | teacher_box_loss: 2.968 | teacher_cls_loss: 5.91 | teacher_dfl_loss: 4.278
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<0
#                    all          4         17          0          0          0          0
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<0
#                    all          4         17          0          0          0          0
# Student subnet metrics: P=0.0000, R=0.0000, mAP50=0.0000, mAP50-95=0.0000
# 2 epochs completed in 0.101 hours.
# Optimizer stripped from runs\detect\train\weights\last.pt, 42.0MB
# Optimizer stripped from runs\detect\train\weights\best.pt, 42.0MB
#
# Validating runs\detect\train\weights\best.pt...
# Ultralytics 8.3.184  Python-3.12.4 torch-2.5.1+cpu CPU (Intel Core(TM) i7-4700HQ 2.40GHz)
# hardcoded_YOLO11n summary (fused): 100 layers, 20,661,736 parameters, 0 gradients, 45.9 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<0
#                    all          4         17          0          0          0          0
#                 person          3         10          0          0          0          0
#                    dog          1          1          0          0          0          0
#                  horse          1          2          0          0          0          0
#               elephant          1          2          0          0          0          0
#               umbrella          1          1          0          0          0          0
#           potted plant          1          1          0          0          0          0
# Speed: 4.7ms preprocess, 826.3ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to runs\detect\train
# Optimizer stripped from runs\detect\train\weights\last_student.pt, 5.5MB
# Optimizer stripped from runs\detect\train\weights\best_student.pt, 5.5MB
#
# Validating runs\detect\train\weights\best_student.pt...
# Ultralytics 8.3.184  Python-3.12.4 torch-2.5.1+cpu CPU (Intel Core(TM) i7-4700HQ 2.40GHz)
# hardcoded_YOLO11n summary (fused): 100 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<0
#                    all          4         17          0          0          0          0
#                      0          3         10          0          0          0          0
#                     16          1          1          0          0          0          0
#                     17          1          2          0          0          0          0
#                     20          1          2          0          0          0          0
#                     25          1          1          0          0          0          0
#                     58          1          1          0          0          0          0
# Speed: 9.3ms preprocess, 226.8ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to runs\detect\train
