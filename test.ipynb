# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

# %%
from ultralytics import YOLO
# model = YOLO("yolo11s.pt")
model = YOLO()
results = model.train(
    data="coco8.yaml", 
    epochs=2, 
    imgsz=640,
    # pretrained=False,
)
# Out:
# No model path provided. Building hardcoded YOLO11n with random initialization.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File E:\00.MOTHER_BOXES\code\self_distillation\ultralytics\engine\model.py:1108, in Model._smart_load(self, key)
#    1107 try:
# -> 1108     return self.task_map[self.task][key]
#    1109 except Exception as e:
#
# KeyError: None
#
# The above exception was the direct cause of the following exception:
#
# NotImplementedError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 from ultralytics import YOLO
#       2 # model = YOLO("yolo11s.pt")
# ----> 3 model = YOLO()
#       4 results = model.train(
#       5     data="coco8.yaml",
#       6     epochs=2,
#       7     imgsz=640,
#       8     # pretrained=False,
#       9 )
#
# ...
